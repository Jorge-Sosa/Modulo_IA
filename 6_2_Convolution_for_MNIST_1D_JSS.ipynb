# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge-Sosa/Modulo_IA/blob/main/6_2_Convolution_for_MNIST_1D_JSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-dkj7ylqt
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-dkj7ylqt
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
    # Entrada: (batch_size, 1, 40)

    nn.Conv1d(
        in_channels=1,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(),

    # Salida: (batch_size, 15, 19)

    nn.Conv1d(
        in_channels=15,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(),

    # Salida: (batch_size, 15, 9)

    nn.Conv1d(
        in_channels=15,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(),

    # Salida: (batch_size, 15, 4)

    nn.Flatten(),

    # 15 × 4 = 60
    nn.Linear(60, 10)
)


#esto es muy FULLy connected, tienes que cambiarla a Convolutional
#usa  nn.Convld y nn.ReLU para las capas convolacionales y nn.Flatten para aplanar la salida antes de la capa lineal final.

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.952016, training error 79.12, validation loss 1.963811, validation error 80.80
# Epoch     1, training loss 1.576367, training error 63.03, validation loss 1.579179, validation error 64.40
# Epoch     2, training loss 1.476363, training error 59.35, validation loss 1.490801, validation error 63.00
# Epoch     3, training loss 1.426484, training error 56.88, validation loss 1.440286, validation error 59.60
# Epoch     4, training loss 1.234090, training error 50.22, validation loss 1.267893, validation error 52.60
# Epoch     5, training loss 1.350525, training error 53.15, validation loss 1.370986, validation error 55.10
# Epoch     6, training loss 1.032522, training error 41.10, validation loss 1.058337, validation error 43.30
# Epoch     7, training loss 0.952322, training error 38.65, validation loss 0.991144, validation error 41.50
# Epoch     8, training loss 1.015822, training error 40.65, validation loss 1.044647, validation error 41.40
# Epoch     9, training loss 0.787727, training error 30.80, validation loss 0.822705, validation error 31.50
# Epoch    10, training loss 0.690293, training error 27.03, validation loss 0.759418, validation error 30.60
# Epoch    11, training loss 0.694093, training error 28.62, validation loss 0.735697, validation error 30.50
# Epoch    12, training loss 0.662727, training error 25.88, validation loss 0.721986, validation error 27.90
# Epoch    13, training loss 0.512522, training error 20.05, validation loss 0.581152, validation error 22.40
# Epoch    14, training loss 0.443056, training error 16.65, validation loss 0.512279, validation error 18.60
# Epoch    15, training loss 0.451503, training error 17.60, validation loss 0.532070, validation error 19.70
# Epoch    16, training loss 0.343679, training error 12.43, validation loss 0.433845, validation error 15.10
# Epoch    17, training loss 0.296347, training error 10.32, validation loss 0.402878, validation error 14.90
# Epoch    18, training loss 0.263432, training error 9.53, validation loss 0.376479, validation error 13.80
# Epoch    19, training loss 0.335165, training error 13.00, validation loss 0.435594, validation error 15.70
# Epoch    20, training loss 0.232264, training error 7.82, validation loss 0.355601, validation error 12.70
# Epoch    21, training loss 0.217451, training error 7.65, validation loss 0.343952, validation error 11.90
# Epoch    22, training loss 0.190883, training error 6.40, validation loss 0.333983, validation error 11.90
# Epoch    23, training loss 0.211613, training error 7.47, validation loss 0.365473, validation error 12.50
# Epoch    24, training loss 0.177696, training error 6.20, validation loss 0.338217, validation error 11.60
# Epoch    25, training loss 0.158950, training error 5.30, validation loss 0.309155, validation error 10.60
# Epoch    26, training loss 0.152108, training error 5.38, validation loss 0.328224, validation error 10.90
# Epoch    27, training loss 0.150710, training error 4.90, validation loss 0.306760, validation error 9.80
# Epoch    28, training loss 0.151570, training error 5.05, validation loss 0.339507, validation error 11.20
# Epoch    29, training loss 0.140176, training error 4.53, validation loss 0.323700, validation error 10.50
# Epoch    30, training loss 0.151025, training error 5.18, validation loss 0.332459, validation error 11.00
# Epoch    31, training loss 0.137588, training error 4.95, validation loss 0.339539, validation error 10.90
# Epoch    32, training loss 0.114066, training error 3.22, validation loss 0.306821, validation error 10.40
# Epoch    33, training loss 0.129826, training error 4.65, validation loss 0.330839, validation error 9.90
# Epoch    34, training loss 0.103964, training error 3.12, validation loss 0.309262, validation error 9.50
# Epoch    35, training loss 0.106911, training error 3.25, validation loss 0.324971, validation error 10.00
# Epoch    36, training loss 0.105237, training error 3.50, validation loss 0.316421, validation error 10.20
# Epoch    37, training loss 0.105698, training error 3.57, validation loss 0.332309, validation error 10.10
# Epoch    38, training loss 0.109656, training error 4.00, validation loss 0.368987, validation error 10.50
# Epoch    39, training loss 0.092433, training error 3.00, validation loss 0.313352, validation error 9.60
# Epoch    40, training loss 0.074301, training error 2.03, validation loss 0.309351, validation error 8.90
# Epoch    41, training loss 0.069470, training error 1.85, validation loss 0.312300, validation error 9.00
# Epoch    42, training loss 0.069747, training error 1.85, validation loss 0.317366, validation error 9.90
# Epoch    43, training loss 0.069852, training error 2.07, validation loss 0.329383, validation error 9.70
# Epoch    44, training loss 0.067188, training error 1.80, validation loss 0.327528, validation error 9.70
# Epoch    45, training loss 0.066360, training error 1.65, validation loss 0.322414, validation error 9.50
# Epoch    46, training loss 0.059737, training error 1.55, validation loss 0.317620, validation error 8.90
# Epoch    47, training loss 0.067285, training error 1.90, validation loss 0.336471, validation error 9.60
# Epoch    48, training loss 0.056098, training error 1.28, validation loss 0.328335, validation error 8.60
# Epoch    49, training loss 0.059127, training error 1.68, validation loss 0.347751, validation error 9.60
# Epoch    50, training loss 0.055235, training error 1.20, validation loss 0.340084, validation error 9.20
# Epoch    51, training loss 0.052945, training error 1.15, validation loss 0.329988, validation error 8.90
# Epoch    52, training loss 0.054619, training error 1.30, validation loss 0.334463, validation error 9.50
# Epoch    53, training loss 0.057895, training error 1.53, validation loss 0.342515, validation error 10.20
# Epoch    54, training loss 0.054129, training error 1.32, validation loss 0.349361, validation error 9.40
# Epoch    55, training loss 0.050925, training error 1.32, validation loss 0.336526, validation error 9.10
# Epoch    56, training loss 0.048028, training error 1.20, validation loss 0.346663, validation error 9.40
# Epoch    57, training loss 0.048628, training error 1.03, validation loss 0.340719, validation error 9.40
# Epoch    58, training loss 0.048915, training error 1.07, validation loss 0.339471, validation error 9.50
# Epoch    59, training loss 0.044561, training error 0.93, validation loss 0.346825, validation error 9.20
# Epoch    60, training loss 0.043391, training error 0.93, validation loss 0.356523, validation error 9.40
# Epoch    61, training loss 0.041542, training error 0.80, validation loss 0.347468, validation error 9.30
# Epoch    62, training loss 0.043487, training error 0.80, validation loss 0.353060, validation error 9.50
# Epoch    63, training loss 0.040234, training error 0.70, validation loss 0.353447, validation error 9.80
# Epoch    64, training loss 0.039630, training error 0.68, validation loss 0.355292, validation error 9.60
# Epoch    65, training loss 0.039452, training error 0.62, validation loss 0.355489, validation error 9.60
# Epoch    66, training loss 0.038392, training error 0.65, validation loss 0.354476, validation error 9.40
# Epoch    67, training loss 0.038461, training error 0.60, validation loss 0.354823, validation error 9.30
# Epoch    68, training loss 0.037485, training error 0.53, validation loss 0.357113, validation error 9.60
# Epoch    69, training loss 0.037660, training error 0.57, validation loss 0.359472, validation error 9.30
# Epoch    70, training loss 0.038649, training error 0.70, validation loss 0.356815, validation error 9.40
# Epoch    71, training loss 0.036870, training error 0.57, validation loss 0.361331, validation error 9.50
# Epoch    72, training loss 0.036358, training error 0.55, validation loss 0.366091, validation error 9.40
# Epoch    73, training loss 0.036473, training error 0.68, validation loss 0.367047, validation error 9.70
# Epoch    74, training loss 0.035126, training error 0.47, validation loss 0.361602, validation error 9.60
# Epoch    75, training loss 0.035224, training error 0.50, validation loss 0.366093, validation error 9.60
# Epoch    76, training loss 0.035332, training error 0.62, validation loss 0.368853, validation error 9.20
# Epoch    77, training loss 0.033610, training error 0.40, validation loss 0.367309, validation error 9.40
# Epoch    78, training loss 0.034107, training error 0.50, validation loss 0.372838, validation error 10.00
# Epoch    79, training loss 0.033194, training error 0.43, validation loss 0.371550, validation error 9.80
# Epoch    80, training loss 0.032626, training error 0.43, validation loss 0.370943, validation error 9.80
# Epoch    81, training loss 0.033768, training error 0.47, validation loss 0.377350, validation error 9.70
# Epoch    82, training loss 0.033414, training error 0.45, validation loss 0.375932, validation error 9.80
# Epoch    83, training loss 0.032235, training error 0.40, validation loss 0.373228, validation error 9.60
# Epoch    84, training loss 0.031792, training error 0.38, validation loss 0.374958, validation error 9.50
# Epoch    85, training loss 0.031340, training error 0.45, validation loss 0.372977, validation error 9.40
# Epoch    86, training loss 0.031627, training error 0.38, validation loss 0.372440, validation error 9.70
# Epoch    87, training loss 0.030926, training error 0.32, validation loss 0.371786, validation error 9.40
# Epoch    88, training loss 0.031075, training error 0.35, validation loss 0.377223, validation error 9.30
# Epoch    89, training loss 0.030681, training error 0.38, validation loss 0.374583, validation error 9.40
# Epoch    90, training loss 0.030783, training error 0.43, validation loss 0.375745, validation error 9.50
# Epoch    91, training loss 0.030694, training error 0.38, validation loss 0.374381, validation error 9.50
# Epoch    92, training loss 0.030906, training error 0.45, validation loss 0.376980, validation error 9.70
# Epoch    93, training loss 0.029889, training error 0.38, validation loss 0.374564, validation error 9.40
# Epoch    94, training loss 0.029617, training error 0.30, validation loss 0.376631, validation error 9.30
# Epoch    95, training loss 0.029674, training error 0.38, validation loss 0.378221, validation error 9.30
# Epoch    96, training loss 0.029579, training error 0.38, validation loss 0.376773, validation error 9.50
# Epoch    97, training loss 0.029411, training error 0.35, validation loss 0.379214, validation error 9.60
# Epoch    98, training loss 0.029017, training error 0.28, validation loss 0.377465, validation error 9.40
# Epoch    99, training loss 0.029047, training error 0.40, validation loss 0.380868, validation error 9.30
